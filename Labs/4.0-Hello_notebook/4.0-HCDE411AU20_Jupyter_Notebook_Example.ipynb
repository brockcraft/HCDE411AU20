# %% [markdown]
# # HCDE 411 Jupyter Notebook Example

# %% [markdown]
# # Overview
# This is an example Jupyter Notebook running on a Jupyter Server instance. Everyone has their own server instance and you can run multiple notebooks with it.
#
# This example shows how you should plan to compile your Python exercises so that you can submit them to Canvas. All python code in a Jupyter (iPython) notebook is executable within the notebook. This means that it is reproducible and anyone can understand how you built your solutions in code.
#
# ([Documentation for Jupyter Notebooks is here](https://jupyter-notebook.readthedocs.io/en/stable/index.html))
#
# All content in a Jupyter notebook is organized into either _Text Cells_ or _Code Cells_.

# %% [markdown]
# ## Text Cells
# This is a text cell. You use text cells to provide descriptive information about your work and your code. the text here is formatted in markdown. Here is a [markdown reference](http://commonmark.org/help/) to show you how you can format text.

# %% [markdown]
# ## Code Cells

# %%
# This is a code cell. You put your executable python code here. For example:

print("Hello world!")

# When you execute this cell, the output will be displayed below it:
# Out:
# Hello world!

# %% [markdown]
# ## Working with our example files and starter code
# When you are trying to run homework files, you should click on the link on Canvas to install them into your Jupyter Notebook Server. This will make a a copy of the starter code on your Jupyter notebook server. Go to your server and open the .ipynb file(s) to start editing them.
#
# To upload data files (e.g., .csv files, JOSN files, etc.), you can drag them into the file tree on your server or upload them with the upoad icon. You can also use **%load filename.py** to load an existing Python file into your notebook where you can can edit it as you see fit. Use the %magic command in a code cell to show a list of special Notebook-specific conmands and options.

# %% [markdown]
# You can run Python code interactively in your notebook. Let's make some lists of values:

# %%
# Adapted from Dr. Froehlich's CSE599! Thanks, Jon!
# A list of values
catnumbers = [1, 2, 3, 4, 5]
catcolors = ['White', 'Black', 'B&W', 'Grey', 'Tabby']
print(catnumbers)
print(catcolors)
# Out:
# [1, 2, 3, 4, 5]
# ['White', 'Black', 'B&W', 'Grey', 'Tabby']

# %%
# Let's graph our lists!
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1]) # [left, bottom, width, height]
ax.bar(catcolors,catnumbers)
plt.show()

# %% [markdown]
# ## How to submit your homework to Canvas
#
# When you are ready to submit your notebook, obtain a link from the file menu as shown below and paste it into your Canvas assignment submission.
#
# ![shareable_link.png](shareable_link.png)

# %% [markdown]
# # Fun stuff

# %% [markdown]
# ### Displaying images in your notebook
# (via #stackoverflow)

# %% [markdown]
# There are several ways to post an image in Jupyter notebooks:
#
# **Via HTML:**
# from IPython.display import Image
# from IPython.core.display import HTML
# Image(url= "http://my_site.com/my_picture.jpg")
# You retain the ability to use HTML tags to resize, etc...
#
# Image(url= "http://my_site.com/my_picture.jpg", width=100, height=100)
#
# **Locally**
# You can also display images stored locally, either via relative or absolute path.
#
# PATH = "/Users/reblochonMasque/Documents/Drawings/"
# Image(filename = PATH + "My_picture.jpg", width=100, height=100)
# if the image it wider than the display settings: thanks
#
# use unconfined=True to disable max-width confinement of the image
#
# from IPython.core.display import Image, display
# display(Image('https://i.ytimg.com/vi/j22DmsZEv30/maxresdefault.jpg', width=1900, unconfined=True))
#
# **Or via markdown:**
# for a web image:
#
# ![Python Logo](https://www.python.org/static/community_logos/python-logo.png)
#
# Pay attention not to use either these quotes "" or those '' around the url.
#
# or a local one:
#
# ![Mr Cat!](mr.cat.jpeg)
#
# **Mr. Cat!** (Obviously nothing will show here unless you have an image stored locally!)

# %% [markdown]
# ### Additional Resources

# %% [markdown]
# #### Markdown Cheatsheet Reference

# %% [markdown]
# https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#emphasis

# %% [markdown]
# #### Jupyter notebook Documentation (Getting Started Guide)

# %% [markdown]
# https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/

# %% [markdown]
# #### How notebooks work
# Notebook documents contains the inputs and outputs of a interactive session as well as additional text that accompanies the code but is not meant for execution. In this way, notebook files can serve as a complete computational record of a session, interleaving executable code with explanatory text, mathematics, and rich representations of resulting objects. These documents are internally JSON files and are saved with the .ipynb extension. Since JSON is a plain text format, they can be version-controlled and shared with colleagues.

# %% [markdown]
# #### Pandas documentation (a python data analysis toolkit)

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/index.html
